# %%
import random

l=("Keyboard", "Trackpad", "Display", "Webcam", "Charger")
word = random.choice(l).lower()
a=5
guess = list("_"*len(word))
print("WELCOME TO THE GAME")
print("Guess word:"," ".join(guess))

while a > 0 and "_" in guess:
    lett =input("Enter a letter: ").lower()
    if lett in word:
        for i in range(len(word)):
            if word[i]== lett:
                guess[i]= lett
        print("Correct!")        
        print(" ".join(guess))
    else:
        a -= 1
        print(f"Wrong!{a} attempts remaining")
        print("".join(guess))
    print()
if "_ " not in guess:
    print(F"Congratulations! You won! The word was:{word}")
else:
    print(f"You Lost! The word was: {word}")
# Out:
# WELCOME TO THE GAME
# Guess word: _______
# Enter a letter:  a
# Correct!
# _ _ a _ _ _ _
# Enter a letter:  t
# Wrong!4 attempts remaining
# __a____
# Enter a letter:  c
# Correct!
# c _ a _ _ _ _
# Enter a letter:  h
# Correct!
# c h a _ _ _ _
# Enter a letter:  r
# Correct!
# c h a r _ _ r
# Enter a letter:  g
# Correct!
# c h a r g _ r
# Enter a letter:  e
# Correct!
# c h a r g e r
#
# Congratulations! You won! The word was:charger
